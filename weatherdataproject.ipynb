# %% [markdown]
# <a href="https://colab.research.google.com/github/Kihorocodes/Kihorocodes/blob/main/weatherdataproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %%
weather_data = pd.read_csv('weatherdata.csv')

# %%
weather_data.head()
# Out:
#    location  temperature  humidity  wind_speed  precipitation  \
# 0   eldoret        114.6      29.3        48.6           1.05
# 1  murang'a         -2.5      98.1         1.8           6.06
# 2  murang'a         22.2      71.6        40.4           2.76
# 3  murang'a         36.6      76.0        31.1           1.70
# 4    kisumu         95.6      41.3        35.2           2.43
#
#   weather_condition sunrise_time sunset_time       moon_phase  uv_index  ...  \
# 0             Foggy      2:14 AM     4:13 PM        Full Moon       7.0  ...
# 1             Snowy      4:38 PM     5:24 PM  Waning Crescent       0.2  ...
# 2             Rainy      7:38 AM     6:20 PM  Waxing Crescent       5.9  ...
# 3            Cloudy      1:36 PM     4:51 PM         New Moon       4.2  ...
# 4             Snowy      7:32 PM     7:28 PM  Waning Crescent       8.3  ...
#
#    frost_alert  thunderstorm_alert  tornado_alert  fog_alert  hail_alert  \
# ...

# %%
weather_data.tail()
# Out:
#          location  temperature  humidity  wind_speed  precipitation  \
# 995      murang'a          6.8      47.9        20.3           9.10
# 996  kiambu. meru         38.7      41.1        41.9           0.42
# 997       nairobi         84.5      37.8        13.6           0.71
# 998        kisumu         -6.7      21.8        30.2           8.70
# 999       mombasa        -13.3      77.1        45.5           0.23
#
#     weather_condition sunrise_time sunset_time       moon_phase  uv_index  \
# 995             Rainy      8:02 PM    11:15 AM  Waxing Crescent       4.9
# 996            Cloudy      2:58 AM     3:42 AM        Full Moon       0.7
# 997             Foggy      4:09 PM     2:53 AM  Waxing Crescent       9.4
# 998            Cloudy      1:40 AM    12:47 AM        Full Moon       1.5
# 999             Snowy      1:48 PM    11:50 AM  Waxing Crescent       3.4
#
#      ...  frost_alert  thunderstorm_alert  tornado_alert  fog_alert  \
# ...

# %%
weather_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 30 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   location                1000 non-null   object
#  1   temperature             1000 non-null   float64
#  2   humidity                1000 non-null   float64
#  3   wind_speed              1000 non-null   float64
#  4   precipitation           1000 non-null   float64
#  5   weather_condition       1000 non-null   object
#  6   sunrise_time            1000 non-null   object
#  7   sunset_time             1000 non-null   object
#  8   moon_phase              1000 non-null   object
#  9   uv_index                1000 non-null   float64
#  10  air_quality_index       1000 non-null   int64
#  11  pollen_count            1000 non-null   int64
#  12  sunlight_duration       1000 non-null   float64
#  13  pressure                1000 non-null   float64
# ...

# %%
weather_data.duplicated().sum()
# Out:
# 0

# %%
datacolumns = ['location','temperature','humidity','wind_speed', 'precipitation','visibility']

# %%
weather=weather_data[datacolumns]

# %%
weather.head()
# Out:
#    location  temperature  humidity  wind_speed  precipitation  visibility
# 0   eldoret        114.6      29.3        48.6           1.05        7.48
# 1  murang'a         -2.5      98.1         1.8           6.06        8.78
# 2  murang'a         22.2      71.6        40.4           2.76        2.19
# 3  murang'a         36.6      76.0        31.1           1.70        4.92
# 4    kisumu         95.6      41.3        35.2           2.43        8.64

# %%
weather.shape
# Out:
# (1000, 6)

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   location       1000 non-null   object
#  1   temperature    1000 non-null   float64
#  2   humidity       1000 non-null   float64
#  3   wind_speed     1000 non-null   float64
#  4   precipitation  1000 non-null   float64
#  5   visibility     1000 non-null   float64
# dtypes: float64(5), object(1)
# memory usage: 47.0+ KB

# %%
weather.nunique()
# Out:
# location           7
# temperature      708
# humidity         635
# wind_speed       425
# precipitation    614
# visibility       644
# dtype: int64

# %%
weather.isnull()
# Out:
#      location  temperature  humidity  wind_speed  precipitation  visibility
# 0       False        False     False       False          False       False
# 1       False        False     False       False          False       False
# 2       False        False     False       False          False       False
# 3       False        False     False       False          False       False
# 4       False        False     False       False          False       False
# ..        ...          ...       ...         ...            ...         ...
# 995     False        False     False       False          False       False
# 996     False        False     False       False          False       False
# 997     False        False     False       False          False       False
# 998     False        False     False       False          False       False
# 999     False        False     False       False          False       False
#
# [1000 rows x 6 columns]

# %%
weather.isnull().sum()
# Out:
# location         0
# temperature      0
# humidity         0
# wind_speed       0
# precipitation    0
# visibility       0
# dtype: int64

# %%
sb.regplot(data= weather, x="temperature",y="humidity", color="r")
# Out:
# <Axes: xlabel='temperature', ylabel='humidity'>

# %%
sb.regplot(data= weather, x="temperature",y="humidity", color="r")
plt.title("Relation between the temperature and humidity in Kenya")
plt.savefig('plot1.png', dpi=300, bbox_inches='tight')
plt.show()
